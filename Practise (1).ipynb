# %%
class MyClass():
    pass

# %%
import pandas as pd
class MyClass():
    def readcsv(filename):
        df=pd.read_csv(filename)
        return df
    
#MyClass.readcsv('datafiles/Match.csv')

# %%
mc=MyClass()
mc.readcsv('datafiles/Match.csv')
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
mc=MyClass
mc.readcsv('datafiles/Match.csv')
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
import pandas as pd
import numpy as np
class wins():
    def readcsv(self,filename):
        df=pd.read_csv(filename)
        return df
    def winlist(self,filename):
        df=a.readcsv(filename)
        team,matchwin=[],[]
        for i in df.values:
            team.append(i[10])
        uniq,matchwin=np.unique(team,return_counts=True)
        return uniq,matchwin
a=wins()
#uniq,matchwin=a.winlist()
import matplotlib.pyplot as plt
labels,sizes=a.winlist('datafiles/Match.csv')
#sizes=matchwin
plt.pie(sizes,labels=labels,autopct='%1.1f',shadow=True,startangle=90)
plt.title('wins',fontsize=20)
plt.axis('equal')
plt.show()

# %%
import pandas as pd
import numpy as np
class wins():
    
    def winlist(self,filename):
        def readcsv(filename):
            df=pd.read_csv(filename)
            return df
        df=readcsv(filename)
        team,matchwin=[],[]
        for i in df.values:
            team.append(i[10])
        uniq,matchwin=np.unique(team,return_counts=True)
        return uniq,matchwin
a=wins()
#uniq,matchwin=a.winlist()
import matplotlib.pyplot as plt
labels,sizes=a.winlist('datafiles/Match.csv')
#sizes=matchwin
plt.pie(sizes,labels=labels,autopct='%1.1f',shadow=True,startangle=90)
plt.title('wins',fontsize=20)
plt.axis('equal')
plt.show()

# %%
import pandas as pd
import numpy as np
class wins():
    def readcsv(filename):
        df=pd.read_csv(filename)
        return df
    def winlist(filename):
        df=wins.readcsv(filename)
        team,matchwin=[],[]
        for i in df.values:
            team.append(i[10])
        uniq,matchwin=np.unique(team,return_counts=True)
        return uniq,matchwin
#uniq,matchwin=a.winlist()
import matplotlib.pyplot as plt
labels,sizes=wins.winlist('datafiles/Match.csv')
#sizes=matchwin
plt.pie(sizes,labels=labels,autopct='%1.1f',shadow=True,startangle=90)
plt.title('wins',fontsize=20)
plt.axis('equal')
plt.show()

# %%
class Sum():
    def __init__(self,a,b):
        print("Hello")
s=Sum(3,5)
# Out:
# Hello

# %%
class Sample():
    def __init__(self,filename):
        df=pd.read_csv(filename)
        print(df)
s=Sample('datafiles/Match.csv')
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
class Sum():
    def __init__(self,a,b):
        return 
s=Sum(3,5)
