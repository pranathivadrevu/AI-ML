# %%
## Read with Relative Path

# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\purchase_data.csv') # as it z comma separated values it returns dataframe
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain   NaN  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      NaN       Yes

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain   NaN  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      NaN       Yes

# %%
# fillna()

# %%
data.fillna(0)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain   0.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      0.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   0.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      0.0       Yes

# %%
data.fillna(method='ffill')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  44.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  35.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  83000.0       Yes

# %%
data.fillna(method='bfill')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  30.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  58000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  48.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      NaN       Yes

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain   NaN  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      NaN       Yes

# %%
data.fillna(method ="ffill", axis = 'columns')
# Out:
#    Country    Age Salary Purchased
# 0   France     44  72000        No
# 1    Spain  Spain  48000       Yes
# 2  Germany     30  54000        No
# 3    Spain     38  61000        No
# 4  Germany     40     40       Yes
# 5   France     35  58000       Yes
# 6    Spain  Spain  52000        No
# 7   France     48  79000       Yes
# 8  Germany     50  83000        No
# 9   France     37     37       Yes

# %%
data.interpolate()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  37.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  83000.0       Yes

# %%
orginal=data
a=orginal

# %%
a
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain   NaN  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      NaN       Yes

# %%
data.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain   NaN  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      NaN       Yes

# %%
data.dropna(how='all')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain   NaN  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0      NaN       Yes

# %%
data.dropna(how='any')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No

# %%
from sklearn.preprocessing import Imputer

# %%
imp = Imputer(missing_values='NaN',strategy='mean',axis=0)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
imp=imp.fit(data.iloc[:,1:3])

# %%
data.iloc[:,1:3]=imp.transform(data.iloc[:,1:3])

# %%
data
# Out:
#    Country    Age   Salary Purchased
# 0   France  44.00  72000.0        No
# 1    Spain  40.25  48000.0       Yes
# 2  Germany  30.00  54000.0        No
# 3    Spain  38.00  61000.0        No
# 4  Germany  40.00  63375.0       Yes
# 5   France  35.00  58000.0       Yes
# 6    Spain  40.25  52000.0        No
# 7   France  48.00  79000.0       Yes
# 8  Germany  50.00  83000.0        No
# 9   France  37.00  63375.0       Yes

# %%
#col=['Purchased']
#data[col]=data[col].fillna(data.mode().iloc[0])
#data[col] = data[col].fillna(data[col].mode().iloc[0])
data['Purchased']=data['Purchased'].fillna(data['Purchased'].mode()[0], inplace=True)
data['Purchased']
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# Name: Purchased, dtype: object

# %%
data
# Out:
#    Country    Age   Salary Purchased
# 0   France  44.00  72000.0      None
# 1    Spain  40.25  48000.0      None
# 2  Germany  30.00  54000.0      None
# 3    Spain  38.00  61000.0      None
# 4  Germany  40.00  63375.0      None
# 5   France  35.00  58000.0      None
# 6    Spain  40.25  52000.0      None
# 7   France  48.00  79000.0      None
# 8  Germany  50.00  83000.0      None
# 9   France  37.00  63375.0      None

# %%
orginal.fillna(orginal.mean())
# Out:
#    Country    Age   Salary Purchased
# 0   France  44.00  72000.0      None
# 1    Spain  40.25  48000.0      None
# 2  Germany  30.00  54000.0      None
# 3    Spain  38.00  61000.0      None
# 4  Germany  40.00  63375.0      None
# 5   France  35.00  58000.0      None
# 6    Spain  40.25  52000.0      None
# 7   France  48.00  79000.0      None
# 8  Germany  50.00  83000.0      None
# 9   France  37.00  63375.0      None

# %%
a
# Out:
#    Country    Age   Salary Purchased
# 0   France  44.00  72000.0      None
# 1    Spain  40.25  48000.0      None
# 2  Germany  30.00  54000.0      None
# 3    Spain  38.00  61000.0      None
# 4  Germany  40.00  63375.0      None
# 5   France  35.00  58000.0      None
# 6    Spain  40.25  52000.0      None
# 7   France  48.00  79000.0      None
# 8  Germany  50.00  83000.0      None
# 9   France  37.00  63375.0      None

# %%
orginal
# Out:
#    Country    Age   Salary Purchased
# 0   France  44.00  72000.0      None
# 1    Spain  40.25  48000.0      None
# 2  Germany  30.00  54000.0      None
# 3    Spain  38.00  61000.0      None
# 4  Germany  40.00  63375.0      None
# 5   France  35.00  58000.0      None
# 6    Spain  40.25  52000.0      None
# 7   France  48.00  79000.0      None
# 8  Germany  50.00  83000.0      None
# 9   France  37.00  63375.0      None

# %%
dset=pd.get_dummies(data.Country)
dset
# Out:
#    France  Germany  Spain
# 0       1        0      0
# 1       0        0      1
# 2       0        1      0
# 3       0        0      1
# 4       0        1      0
# 5       1        0      0
# 6       0        0      1
# 7       1        0      0
# 8       0        1      0
# 9       1        0      0

# %%
merge=pd.concat([data,dset],axis=1)

# %%
merge
# Out:
#    Country    Age   Salary Purchased  France  Germany  Spain
# 0   France  44.00  72000.0        No       1        0      0
# 1    Spain  40.25  48000.0       Yes       0        0      1
# 2  Germany  30.00  54000.0        No       0        1      0
# 3    Spain  38.00  61000.0        No       0        0      1
# 4  Germany  40.00  63375.0       Yes       0        1      0
# 5   France  35.00  58000.0       Yes       1        0      0
# 6    Spain  40.25  52000.0        No       0        0      1
# 7   France  48.00  79000.0       Yes       1        0      0
# 8  Germany  50.00  83000.0        No       0        1      0
# 9   France  37.00  63375.0       Yes       1        0      0

# %%
pd.get_dummies(data,columns=['Country'],drop_first=True)
#pd.get_dummies(price, columns = ['town'], drop_first = True)
# Out:
#      Age   Salary Purchased  Country_Germany  Country_Spain
# 0  44.00  72000.0        No                0              0
# 1  40.25  48000.0       Yes                0              1
# 2  30.00  54000.0        No                1              0
# 3  38.00  61000.0        No                0              1
# 4  40.00  63375.0       Yes                1              0
# 5  35.00  58000.0       Yes                0              0
# 6  40.25  52000.0        No                0              1
# 7  48.00  79000.0       Yes                0              0
# 8  50.00  83000.0        No                1              0
# 9  37.00  63375.0       Yes                0              0

# %%
a=merge.drop(['Country','Spain'],axis=1)

# %%
a
# Out:
#      Age   Salary Purchased  France  Germany
# 0  44.00  72000.0        No       1        0
# 1  40.25  48000.0       Yes       0        0
# 2  30.00  54000.0        No       0        1
# 3  38.00  61000.0        No       0        0
# 4  40.00  63375.0       Yes       0        1
# 5  35.00  58000.0       Yes       1        0
# 6  40.25  52000.0        No       0        0
# 7  48.00  79000.0       Yes       1        0
# 8  50.00  83000.0        No       0        1
# 9  37.00  63375.0       Yes       1        0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
coun=data

# %%
coun.Country=le.fit_transform(data.Country)
coun
# Out:
#    Country    Age   Salary Purchased
# 0        0  44.00  72000.0        No
# 1        2  40.25  48000.0       Yes
# 2        1  30.00  54000.0        No
# 3        2  38.00  61000.0        No
# 4        1  40.00  63375.0       Yes
# 5        0  35.00  58000.0       Yes
# 6        2  40.25  52000.0        No
# 7        0  48.00  79000.0       Yes
# 8        1  50.00  83000.0        No
# 9        0  37.00  63375.0       Yes

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
purch=data

# %%
purch.

# %%
# Dummy set for purchase

# %%
pset=pd.get_dummies(data.Purchased)
pset
# Out:
#    No  Yes
# 0   1    0
# 1   0    1
# 2   1    0
# 3   1    0
# 4   0    1
# 5   0    1
# 6   1    0
# 7   0    1
# 8   1    0
# 9   0    1

# %%
pmerge=pd.concat([data,pset],axis=1)
pmerge
# Out:
#    Country    Age   Salary Purchased  No  Yes
# 0        0  44.00  72000.0        No   1    0
# 1        2  40.25  48000.0       Yes   0    1
# 2        1  30.00  54000.0        No   1    0
# 3        2  38.00  61000.0        No   1    0
# 4        1  40.00  63375.0       Yes   0    1
# 5        0  35.00  58000.0       Yes   0    1
# 6        2  40.25  52000.0        No   1    0
# 7        0  48.00  79000.0       Yes   0    1
# 8        1  50.00  83000.0        No   1    0
# 9        0  37.00  63375.0       Yes   0    1

# %%
pd.get_dummies(data,columns=['Purchased'],drop_first=True)
# Out:
#    Country    Age   Salary  Purchased_Yes
# 0        0  44.00  72000.0              0
# 1        2  40.25  48000.0              1
# 2        1  30.00  54000.0              0
# 3        2  38.00  61000.0              0
# 4        1  40.00  63375.0              1
# 5        0  35.00  58000.0              1
# 6        2  40.25  52000.0              0
# 7        0  48.00  79000.0              1
# 8        1  50.00  83000.0              0
# 9        0  37.00  63375.0              1

# %%
dataset=pmerge.drop(['Purchased','Yes'],axis=1)
#a=merge.drop(['Country','Spain'],axis=1)

# %%
dataset
# Out:
#    Country    Age   Salary  No
# 0        0  44.00  72000.0   1
# 1        2  40.25  48000.0   0
# 2        1  30.00  54000.0   1
# 3        2  38.00  61000.0   1
# 4        1  40.00  63375.0   0
# 5        0  35.00  58000.0   0
# 6        2  40.25  52000.0   1
# 7        0  48.00  79000.0   0
# 8        1  50.00  83000.0   1
# 9        0  37.00  63375.0   0

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(categorical_features = [0])
x = ohe.fit_transform(dataset).toarray()
x
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:392: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# array([[1.0000e+00, 0.0000e+00, 0.0000e+00, 4.4000e+01, 7.2000e+04,
#         1.0000e+00],
# ...

# %%
x=pd.DataFrame(x)
x
# Out:
#      0    1    2      3        4    5
# 0  1.0  0.0  0.0  44.00  72000.0  1.0
# 1  0.0  0.0  1.0  40.25  48000.0  0.0
# 2  0.0  1.0  0.0  30.00  54000.0  1.0
# 3  0.0  0.0  1.0  38.00  61000.0  1.0
# 4  0.0  1.0  0.0  40.00  63375.0  0.0
# 5  1.0  0.0  0.0  35.00  58000.0  0.0
# 6  0.0  0.0  1.0  40.25  52000.0  1.0
# 7  1.0  0.0  0.0  48.00  79000.0  0.0
# 8  0.0  1.0  0.0  50.00  83000.0  1.0
# 9  1.0  0.0  0.0  37.00  63375.0  0.0

# %%
dataset
# Out:
#    Country    Age   Salary  No
# 0        0  44.00  72000.0   1
# 1        2  40.25  48000.0   0
# 2        1  30.00  54000.0   1
# 3        2  38.00  61000.0   1
# 4        1  40.00  63375.0   0
# 5        0  35.00  58000.0   0
# 6        2  40.25  52000.0   1
# 7        0  48.00  79000.0   0
# 8        1  50.00  83000.0   1
# 9        0  37.00  63375.0   0

# %%
coun
# Out:
#    Country    Age   Salary Purchased
# 0        0  44.00  72000.0        No
# 1        2  40.25  48000.0       Yes
# 2        1  30.00  54000.0        No
# 3        2  38.00  61000.0        No
# 4        1  40.00  63375.0       Yes
# 5        0  35.00  58000.0       Yes
# 6        2  40.25  52000.0        No
# 7        0  48.00  79000.0       Yes
# 8        1  50.00  83000.0        No
# 9        0  37.00  63375.0       Yes

# %%
X=coun.iloc[:,0:3]
X
# Out:
#    Country    Age   Salary
# 0        0  44.00  72000.0
# 1        2  40.25  48000.0
# 2        1  30.00  54000.0
# 3        2  38.00  61000.0
# 4        1  40.00  63375.0
# 5        0  35.00  58000.0
# 6        2  40.25  52000.0
# 7        0  48.00  79000.0
# 8        1  50.00  83000.0
# 9        0  37.00  63375.0

# %%
y=coun.Purchased
y
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8     No
# 9    Yes
# Name: Purchased, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8, 3)
# (2, 3)
# (8,)
# (2,)

# %%
dataset
# Out:
#    Country    Age   Salary  No
# 0        0  44.00  72000.0   1
# 1        2  40.25  48000.0   0
# 2        1  30.00  54000.0   1
# 3        2  38.00  61000.0   1
# 4        1  40.00  63375.0   0
# 5        0  35.00  58000.0   0
# 6        2  40.25  52000.0   1
# 7        0  48.00  79000.0   0
# 8        1  50.00  83000.0   1
# 9        0  37.00  63375.0   0

# %%
from sklearn.preprocessing import scale
a = scale(dataset)
a
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype uint8, int32, float64 were all converted to float64 by the scale function.
# array([[-1.08347268,  0.66551738,  0.7900303 ,  1.        ],
#        [ 1.32424438,  0.        , -1.40831488, -1.        ],
#        [ 0.12038585, -1.81908084, -0.85872859,  1.        ],
#        [ 1.32424438, -0.39931043, -0.21754458,  1.        ],
#        [ 0.12038585, -0.04436783,  0.        , -1.        ],
#        [-1.08347268, -0.93172433, -0.49233772, -1.        ],
#        [ 1.32424438,  0.        , -1.04192402,  1.        ],
#        [-1.08347268,  1.37540259,  1.43121431, -1.        ],
#        [ 0.12038585,  1.73034519,  1.79760518,  1.        ],
#        [-1.08347268, -0.57678173,  0.        , -1.        ]])

# %%
b=pd.DataFrame(a)
b
# Out:
#           0         1         2    3
# 0 -1.083473  0.665517  0.790030  1.0
# 1  1.324244  0.000000 -1.408315 -1.0
# 2  0.120386 -1.819081 -0.858729  1.0
# 3  1.324244 -0.399310 -0.217545  1.0
# 4  0.120386 -0.044368  0.000000 -1.0
# 5 -1.083473 -0.931724 -0.492338 -1.0
# 6  1.324244  0.000000 -1.041924  1.0
# 7 -1.083473  1.375403  1.431214 -1.0
# 8  0.120386  1.730345  1.797605  1.0
# 9 -1.083473 -0.576782  0.000000 -1.0

# %%
from sklearn.preprocessing import scale
a = scale(X)
a
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by the scale function.
# array([[-1.08347268,  0.66551738,  0.7900303 ],
#        [ 1.32424438,  0.        , -1.40831488],
#        [ 0.12038585, -1.81908084, -0.85872859],
#        [ 1.32424438, -0.39931043, -0.21754458],
#        [ 0.12038585, -0.04436783,  0.        ],
#        [-1.08347268, -0.93172433, -0.49233772],
#        [ 1.32424438,  0.        , -1.04192402],
#        [-1.08347268,  1.37540259,  1.43121431],
#        [ 0.12038585,  1.73034519,  1.79760518],
#        [-1.08347268, -0.57678173,  0.        ]])

# %%
from sklearn.preprocessing import scale
a = scale(y)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-5b57603e9818> in <module>
#       1 from sklearn.preprocessing import scale
# ----> 2 a = scale(y)
#       3 a
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     147     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     148                     warn_on_dtype=True, estimator='the scale function',
# --> 149                     dtype=FLOAT_DTYPES, force_all_finite='allow-nan')
#     150     if sparse.issparse(X):
#     151         if with_mean:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
# ...
